# %% [markdown]
# **Data Types and Structures**
#
# 1.  What are data structures, and why are they important
#
#     Data structure is a way to store and organize data so that it can be efficiently accessed and manipulated.
#     It defines how data is stored, how it can be accessed, and how operations like insert, delete, search, and update are performed.
#
#     * Choosing the right data structure makes programs faster and saves memory.
#
#     * Helps manage large amounts of data in a logical way.
#
#     * Makes adding, deleting, and searching data easier.
#
#     * Most algorithms rely on the correct data structure.
#
#     * Simplifies complex problems by storing data in the right way.
#
#
# 2. Explain the difference between mutable and immutable data types with examples
#
#     Mutable are which can be changed after creation.
#
#        Ex: List, Dictonary, set
#
#     Immutable are which can be changed after creation.
#
#        Ex: Tuple, String, Integer
#
#    # Mutable
#
#      ![image.png](data:image/png;base64,...
#      )
#
#    # Immutable
#
#    ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. What are the main differences between lists and tuples in Python?
#
#     1. Mutability:
#
#     The most fundamental difference between lists and tuples is mutability. Lists are mutable, meaning you can modify them after creation—add, remove, or change elements. Tuples, on the other hand, are immutable, so once they are created, their content cannot be changed.
#
#     2. Syntax:
#
#     Lists are defined using square brackets, e.g., mylist = [1, 2, 3], whereas tuples use parentheses, e.g., mytuple = (1, 2, 3)
#
#     3. Performance:
#
#     Tuples are generally faster than lists for iteration and access because they are immutable.Lists, being mutable, require additional memory to support dynamic modifications.
#
#     4. Methods and Functionality:
#
#     Lists provide many built-in methods such as append(), remove(), pop(), sort(), and reverse(), which allow for flexible modification. Tuples have very limited methods, primarily count() and index(), reflecting their immutable nature.

# %% [markdown]
# 4.  Describe how dictionaries store data
#
#     A dictionary in Python is a built-in data structure that stores data as key-value pairs. Each key is unique, and each key maps to a specific value.
#
#     ex: student = {"name": "Nidhi", "age": 25, "course": "Python"}
#
#      * "name", "age", and "course" are keys, and "Nidhi", 25, and "Python" are their corresponding values.
#
#     Python dictionaries are implemented using a hash table. When we add a key-value pair, Python computes a hash value for the key.This hash determines where the value is stored in memory.

# %% [markdown]
# 5.  Why might you use a set instead of a list in Python
#
#     we might Use set instead of list when we need to ensure all elements are unique, Suitable for membership testing and eliminating duplicates.And also ideal for mathematical set operations like union, intersection, and difference.
#
#   ex:
#        ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. What is a string in Python, and how is it different from a list?
#
#    A string in python is a sequence of characters enclosed in quotes. It can include letters, numbers, symbols or spaces. Strings are widely used for text handling and manipulation.
#
#     Key differences from list:
#
#      * lists are mutable which can be changed after creation but strings are immutable in nature.
#
#      * lists Can contain elements of any data type (e.g., integers, strings, etc.). whereas string always contains characters (each character is a string of length 1).
#
#      * lists are enclosed in square brackets ([ ]).But strings enclosed in quotes (' ', " ", or ''' ''').
#
#      * 	Lists Supports list-specific operations like appending, removing, and slicing.String supports string-specific operations like concatenation (+) and slicing.
#
#      * Lists Used for storing collections of items. Strings Primarily used for text handling.

# %% [markdown]
# 7.  How do tuples ensure data integrity in Python?
#
#    Tuples in Python ensure data integrity primarily through their immutability. Once a tuple is created, its elements cannot be modified, added, or removed. This ensures that the data remains consistent and unchanged throughout the program, making tuples ideal for storing constant or critical data.
#
#   Since tuples cannot be modified, they prevent accidental changes to the data. This is particularly useful when passing data between functions or modules, as it guarantees that the original data remains intact.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#
#     A hash table is a data structure that stores key-value pairs. It uses a hash function to compute an index (or hash code) for each key, which determines where the corresponding value is stored in the table. This allows for efficient data retrieval, insertion, and deletion, typically with an average time complexity of O(1).
#
#   * In Python, the dictionary (dict) is an implementation of a hash table. Hash tables, dictionaries store data as key-value pairs.

# %% [markdown]
# 9. Can lists contain different data types in Python?
#
#     Yes lists are heterogeneous in nature. It stores elements of mixed types while allowing duplicates and perform frequent modifications like appending, removing, or sorting elements.
#
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10. Explain why strings are immutable in Python?
#
#     In Python, strings are immutable, meaning their content cannot be changed after they are created. This immutability ensures that once a string object is instantiated, its value remains constant throughout its lifetime.
#
#     For example:
#           ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11.  What advantages do dictionaries offer over lists for certain tasks?
#
#    A key advantage of using dictionaries over lists in Python is their efficiency in searching and accessing elements. Dictionaries are implemented as hash tables, allowing for constant time complexity (O(1)) when retrieving a value using its key. In contrast, lists require a linear search (O(n)), which becomes slower as the list grows larger.

# %% [markdown]
# 12.  Describe a scenario where using a tuple would be preferable over a list?
#
#    A tuple would be preferable over a list when you need to store a fixed collection of items that should not change throughout the program.
#
#    Scenario:
#
#    * storing the geographical coordinates (latitude and longitude) of a location:
#
#    In this case, a tuple is better than a list because the coordinates are constant values that shouldn’t be modified.Tuples are faster and use less memory than lists.Tuples can be used as keys in dictionaries (since they are immutable), whereas lists cannot.
#
#        locations = {
#           (13.0827, 80.2707): "Chennai",
#           (12.9716, 77.5946): "Bangalore"
#        }

# %% [markdown]
# 13.  How do sets handle duplicate values in Python?
#
#    Sets in Python are designed to automatically handle duplicate values by ensuring that each element in the set is unique. When you add duplicate values to a set, Python automatically removes the duplicates and keeps only one instance of each unique value.
#
#      my_set = {1, 2, 2, 3, 4, 4}
#      print(my_set)  # Output: {1, 2, 3, 4}

# %% [markdown]
# 14. How does the “in” keyword work differently for lists and dictionaries?
#
#     The in keyword checks if a value exists within the list. This operation involves iterating through the list sequentially and comparing each element with the target value.
#     ex:
#        list1 = [1,2,3]
#        print(3 in list1)
#        # output: True
#
#     When in used with a dictionary it checks for the presence of a key, not a value. If we want to check for a value, need to use the .values() method explicitly.
#     ex:
#        dict1 = {x:1, y:2, z:3}
#        print(x in dict1)
#        # output: True(checks value)

# %% [markdown]
# 15.  Can you modify the elements of a tuple? Explain why or why not?
#
#   No we cannot modify elements of a tuple.Tuple are immutable in nature, meaning which cannot be changed or modified. Because tuples cannot be modified after creation. Any attempt to change their elements will raise a TypeError.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
#
#     A nested dictionary in Python is a dictionary inside another dictionary. This allows to store complex data structures in a single dictionary. Each key in the outer dictionary can map to another dictionary, enabling hierarchical data storage.
#
#     ex:
#
#        people = {
#
#          1: {'name': 'Nidhi', 'age': '26', 'sex': 'Female'},
#
#          2: {'name': 'Honey', 'age': '24', 'sex': 'Female'}
#
#        }
#
#        print(people[1]['name']) # Output: Nidhi
#
#        print(people[1]['age']) # Output: 26
#
#        print(people[1]['sex']) # Output: Female

# %% [markdown]
# 17.  Describe the time complexity of accessing elements in a dictionary?
#
#
#   Accessing a value in a Python dictionary by its key has an average time complexity of O(1). This efficiency is due to the underlying implementation of dictionaries using hash tables. Hash tables allow for constant-time lookups by computing a hash of the key, which directly maps to a memory location where the value is stored.

# %% [markdown]
# 18.  In what situations are lists preferred over dictionaries?
#
#
#   Lists are preferred over dictionaries in situations where order matters, duplicates are allowed, and when we need to perform operations like appending or iterating through a sequence of items.

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#
#     Dictionaries in Python are often referred to as unordered collections because they do not guarantee any specific order of their elements based on insertion or key values. This characteristic stems from their underlying implementation as hash tables, which prioritize fast key-based lookups over maintaining order.
#
#     It affects data retrieval by:
#     * Key-Based Access- dictionaries do not allow access by index. Instead, we retrieve values using their associated keys
#     * Iteration Order
#     * Performance Optimization

# %% [markdown]
# 20.  Explain the difference between a list and a dictionary in terms of data retrieval?
#
#    A list retrieves data using an index number, meaning we must know the item’s position in the sequence. This can be slower for large lists since Python may need to search through several elements.
#
#   A dictionary, however, retrieves data using a unique key, which is much faster because it uses a hashing mechanism to directly access the value linked to that key.

# %% [markdown]
# ** PRACTICAL QUESTIONS **
#
# 1.  Write a code to create a string with your name and print it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Write a code to find the length of the string "Hello World".
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6.  Write a code to create a list with numbers 1 to 5 and print it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9.  Write a code to access the second element in the list ['a', 'b', 'c', 'd']
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10.  Write a code to reverse the list [10, 20, 30, 40, 50].
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13.  Write a code to find the minimum number in the tuple (10, 20, 5, 15)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14.  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 16.  Write a code to create a set with the elements 'a', 'b', 'c' and print it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18.  Write a code to remove the element 4 from the set {1, 2, 3, 4}.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 21.  Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 25.  Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 26.  Write a code to create a list, a tuple, and a dictionary, and print them all.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 27.  Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 28.  Write a code to create a list with strings and print the element at the third index.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30. Write a code to convert a list of strings into a set.
#
# ![image.png](data:image/png;base64,...)
