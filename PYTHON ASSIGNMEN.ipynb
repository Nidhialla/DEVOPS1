# %% [markdown]
# 1. Explain the key features of Python that make it a popular choice for programming
#
#
#   *   Python is popular because it's easy to learn and read. It has simple, English-like syntax.
#
#        Ex: Print("Hello, World")
#
#   *  It is Interupted language, we can run code line by line. No need to compile.
#
#   *   It supports Object-oriented- Classes and objects
#
#
#
# 2.  Describe the role of predefined keywords in Python and provide examples of how they are used in a
# program
#
#     Predefined keywords are reserved words which have special meaning and cannot be used as identifiers as in variable or function names.
#
#          Ex: if, else, for, while, def, class, return, etc.
#
#      Example Program

# %%
if True:
  print("Python Keyword Example")
else:
  print("not a keyword")

# %% [markdown]
# 3. Compare and contrast mutable and immutable objects in Python with examples
#
#     Mutable are which can be changed after creation.
#
#       Ex: List, Dictonary, set
#
#     Immutable are which can be changed after creation.
#
#       Ex: Tuple, String, Integer
#
#     # mutable
#     ![image.png](data:image/png;base64,...)
#
#     # Immutable
#
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
#
#    * Arithmetic Operators: +, -, *, /, %
#
#       a, b = 10, 3
#
#       print(a + b)
#
#       o/p: 13
#
#    *  Comparision Operators: ==, !>, >, <, >=, <=
#
#       print(a > b)
#
#     * Logical Operators: and, or, not
#
#       print(a > 5 and b < 5)
#
#     * Assignment operators: =, +=, -=, *=
#
#       a +=2 # same as a = a + 2
#
#      * Identity Operators: is, is Not
#
#        print(a is b)
#
#
#  5.  Explain the concept of type casting in Python with examples.
#
#
#     Type casting means converting one data type into another.
#     types: 1. Implicit casting(automatic)- done ny python
#            2. Explicit Casting(manual)- done by user built-in functions.
#
#      Implicit
#         x = 6
#         y = 6.9
#         print(x + y)
#
#     o/p: 12.9
#
#    Explicit
#
#       a = "10"
#       b = int(a)
#       print(b + 5)
#
#     o/p: 15

# %% [markdown]
# 6.   How do conditional statements work in Python? Illustrate with examples
#
#     Conditional statements are used to execute code based on certain conditions.
#
#    ex:
#
#  ![image.png](data:image/png;base64,...)
#
#  Explanation:
#
#   * if checks the first condition.
#   * elif checks additional conditions.
#   * else executes when none of the above are true.

# %% [markdown]
# 7. Describe the different types of loops in Python and their use cases with examples.
#
#     Types of loops:
#
#     * for loop- used to iterate over a sequence (list, string, range).
#
#     * while loop- runs while a condition is true.
#
#     * Nested loops- loop inside another loop.
#
#     * loop control statements:
#
#            break- exit the loop
#            continue- skip the current iteration
#            pass- do nothing.

# %%
# for loop

for i in range(3):
  print(i)

 # output: 0,1,2

# while loop

count = 0
while count < 3:
  print(count)
  count += 1

  # output: 0, 1, 2

# Nested loops

 for i in range(2):
  for j in range(2):
    print(i, j)

    #output: 0 0
             0 1
             1 0
             1 1
